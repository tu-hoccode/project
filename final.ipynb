# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("processing/data_final.csv")

# %%
df.head()
# Out:
#                             path_a  \
# 0  images_png/camera/194121937.png
# 1   images_png/phone/273990229.png
# 2  images_png/camera/275938579.png
# 3   images_png/phone/276274790.png
# 4   images_png/phone/276639232.png
#
#                                              title_a  \
# 0  Camera IP Wifi Ngoài Trời EZVIZ C3TN 3MP 2K Co...
# 1  Điện Thoại Xiaomi Redmi Note 13 6GB/128GB - Hà...
# 2  Camera trong nhà TP-Link Tapo TC60 - Full HD, ...
# 3  Điện Thoại Samsung Galaxy A06 4GB/128GB - Hàng...
# 4  Điện Thoại Samsung Galaxy A16 5G 8GB/128GB - H...
#
#                             path_b  \
# 0  images_png/camera/194130039.png
# 1   images_png/phone/276944892.png
# 2   images_png/phone/277777809.png
# 3   images_png/phone/276944892.png
# 4   images_png/phone/276944868.png
#
#                                              title_b  duplicate
# 0  Camera IP Wifi Ngoài Trời EZVIZ H3 5MP Độ Phân...       True
# 1  Điện Thoại Samsung Galaxy A06 4GB/64GB - Hàng ...       True
# 2  Điện thoại Samsung Galaxy A26 5G (8/128GB), Mặ...      False
# 3  Điện Thoại Samsung Galaxy A06 4GB/64GB - Hàng ...       True
# 4  Điện Thoại Samsung Galaxy A16 4GB/128GB - Hàng...       True

# %%
df.shape
# Out:
# (520, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   path_a     520 non-null    object
#  1   title_a    520 non-null    object
#  2   path_b     520 non-null    object
#  3   title_b    520 non-null    object
#  4   duplicate  520 non-null    bool
# dtypes: bool(1), object(4)
# memory usage: 16.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['duplicate'] = encoder.fit_transform(df['duplicate'])

# %%
df.head()
# Out:
#                             path_a  \
# 0  images_png/camera/194121937.png
# 1   images_png/phone/273990229.png
# 2  images_png/camera/275938579.png
# 3   images_png/phone/276274790.png
# 4   images_png/phone/276639232.png
#
#                                              title_a  \
# 0  Camera IP Wifi Ngoài Trời EZVIZ C3TN 3MP 2K Co...
# 1  Điện Thoại Xiaomi Redmi Note 13 6GB/128GB - Hà...
# 2  Camera trong nhà TP-Link Tapo TC60 - Full HD, ...
# 3  Điện Thoại Samsung Galaxy A06 4GB/128GB - Hàng...
# 4  Điện Thoại Samsung Galaxy A16 5G 8GB/128GB - H...
#
#                             path_b  \
# 0  images_png/camera/194130039.png
# 1   images_png/phone/276944892.png
# 2   images_png/phone/277777809.png
# 3   images_png/phone/276944892.png
# 4   images_png/phone/276944868.png
#
#                                              title_b  duplicate
# 0  Camera IP Wifi Ngoài Trời EZVIZ H3 5MP Độ Phân...          1
# 1  Điện Thoại Samsung Galaxy A06 4GB/64GB - Hàng ...          1
# 2  Điện thoại Samsung Galaxy A26 5G (8/128GB), Mặ...          0
# 3  Điện Thoại Samsung Galaxy A06 4GB/64GB - Hàng ...          1
# 4  Điện Thoại Samsung Galaxy A16 4GB/128GB - Hàng...          1

# %%
# missing values
df.isnull().sum()
# Out:
# path_a       0
# title_a      0
# path_b       0
# title_b      0
# duplicate    0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df['duplicate'].value_counts()
# Out:
# duplicate
# 1    260
# 0    260
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['duplicate'].value_counts(), labels=['duplicate','no duplicate'],autopct="%0.2f")
plt.show()
