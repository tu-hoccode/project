# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_tv.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  278220734  2004742899164
# 1  278138258  5502954751332
# 2  278077419  1516540466887
# 3  278077327  2768528301218
# 4  278009387  8760632727779
#
#                                                 name  \
# 0  [NEW 2026 TV Series] Smart Tivi Xiaomi TV A Pr...
# 1  Smart Tivi LG AI 4K 55 Inch 55UA8450PSA- Hàng ...
# 2  Google Tivi Xiaomi A 2026 4K 55 inch L55MB-ASE...
# 3  Google Tivi Xiaomi A 2026 4K 43 inch L43MB-AUS...
# 4  Google Tivi Coocaa Full. HD 43 inch  43Z73 - h...
#
#                                              url_key  \
# 0  new-2026-tv-series-smart-tivi-xiaomi-tv-a-pro-...
# 1  smart-tivi-lg-ai-4k-55-inch-55ua8450psa-hang-c...
# 2  google-tivi-xiaomi-a-2026-4k-55-inch-l55mb-ase...
# 3  google-tivi-xiaomi-a-2026-4k-43-inch-l43mb-aus...
# 4  google-tivi-coocaa-full-hd-43-inch-43z73-p2780...
#
#                                             url_path  type  author_name  \
# 0  new-2026-tv-series-smart-tivi-xiaomi-tv-a-pro-...   NaN          NaN
# 1  smart-tivi-lg-ai-4k-55-inch-55ua8450psa-hang-c...   NaN          NaN
# 2  google-tivi-xiaomi-a-2026-4k-55-inch-l55mb-ase...   NaN          NaN
# 3  google-tivi-xiaomi-a-2026-4k-43-inch-l43mb-aus...   NaN          NaN
# 4  google-tivi-coocaa-full-hd-43-inch-43z73-p2780...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  \
# 0         NaN     Xiaomi                NaN  ...
# 1         NaN         LG                NaN  ...
# 2         NaN     Xiaomi                NaN  ...
# 3         NaN     Xiaomi                NaN  ...
# 4         NaN     coocaa                NaN  ...
#
#    badges_new_4_arr_text_0_value  badges_new_4_text_color badges_new_4_icon  \
# 0                            NaN                      NaN               NaN
# 1                            NaN                      NaN               NaN
# 2                            NaN                      NaN               NaN
# 3                            NaN                      NaN               NaN
# 4                            NaN                      NaN               NaN
#
#   badges_new_4_icon_height  badges_new_4_icon_width  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#    badges_new_3_promotions_0_icon badges_new_3_promotions_0_icon_height  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
#
#   badges_new_3_promotions_0_icon_width badges_new_3_promotions_0_text  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
#
#   visible_impression_info_amplitude_ineligible_coupon_rule_id
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 165 columns]

# %%
keep_cols = [ 
    "name", 
    "image_path", 
    "thumbnail_url"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#                                                title                     path  \
# 0  [NEW 2026 TV Series] Smart Tivi Xiaomi TV A Pr...  images/tv/278220734.jpg
# 1  Smart Tivi LG AI 4K 55 Inch 55UA8450PSA- Hàng ...  images/tv/278138258.png
# 2  Google Tivi Xiaomi A 2026 4K 55 inch L55MB-ASE...  images/tv/278077419.jpg
# 3  Google Tivi Xiaomi A 2026 4K 43 inch L43MB-AUS...  images/tv/278077327.png
# 4  Google Tivi Coocaa Full. HD 43 inch  43Z73 - h...  images/tv/278009387.png
#
#                                                  url
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   100 non-null    object
#  1   path    100 non-null    object
#  2   url     100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB
#                                                     title  \
# count                                                 100
# unique                                                100
# top     [NEW 2026 TV Series] Smart Tivi Xiaomi TV A Pr...
# freq                                                    1
#
#                            path  \
# count                       100
# unique                      100
# top     images/tv/278220734.jpg
# freq                          1
#
#                                                       url
# count                                                 100
# unique                                                100
# top     https://salt.tikicdn.com/cache/280x280/ts/prod...
# freq                                                    1

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.to_excel("../data_cleaned/tv.xlsx", index=False)
