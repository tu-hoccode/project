# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_laptop.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  278226869  2945221924243
# 1  278226504  8916945952669
# 2  278078317  3260486333768
# 3  278078298  4377873239825
# 4  278078286  8288406691059
#
#                                                 name  \
# 0  Laptop Dell Inspiron 3530 71043887( Core i5-13...
# 1  Laptop Dell Inspiron 15 3530 N3530-i3U085W11SL...
# 2  Asus Vivobook S 14 Flip TP3402VA-LZ632W (Intel...
# 3  Asus Vivobook 15 X1502VA-BQ886W (Intel Core i7...
# 4  Asus Vivobook 14 X1405VA-LY623W (Intel Core i5...
#
#                                              url_key  \
# 0  laptop-dell-inspiron-3530-71043887-core-i5-133...
# 1  laptop-dell-inspiron-15-3530-n3530-i3u085w11sl...
# 2  asus-vivobook-s-14-flip-tp3402va-lz632w-intel-...
# 3  asus-vivobook-15-x1502va-bq886w-intel-core-i7-...
# 4  asus-vivobook-14-x1405va-ly623w-intel-core-i5-...
#
#                                             url_path  type  author_name  \
# 0  laptop-dell-inspiron-3530-71043887-core-i5-133...   NaN          NaN
# 1  laptop-dell-inspiron-15-3530-n3530-i3u085w11sl...   NaN          NaN
# 2  asus-vivobook-s-14-flip-tp3402va-lz632w-intel-...   NaN          NaN
# 3  asus-vivobook-15-x1502va-bq886w-intel-core-i7-...   NaN          NaN
# 4  asus-vivobook-14-x1405va-ly623w-intel-core-i5-...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  badges_new_6_type  \
# 0         NaN       Dell                NaN  ...                NaN
# 1         NaN       Dell                NaN  ...                NaN
# 2         NaN       Asus                NaN  ...                NaN
# 3         NaN       Asus                NaN  ...                NaN
# 4         NaN       Asus                NaN  ...                NaN
#
#    visible_impression_info_amplitude_gift_rule_ids badges_new_3_icon  \
# 0                                              NaN               NaN
# 1                                              NaN               NaN
# 2                                              NaN               NaN
# 3                                              NaN               NaN
# 4                                              NaN               NaN
#
#   badges_new_3_icon_height  badges_new_3_icon_width  badges_new_2_icon  \
# 0                      NaN                      NaN                NaN
# 1                      NaN                      NaN                NaN
# 2                      NaN                      NaN                NaN
# 3                      NaN                      NaN                NaN
# 4                      NaN                      NaN                NaN
#
#   badges_new_2_icon_height badges_new_2_icon_width  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
#
#   badges_new_3_arr_text_0_value badges_new_4_arr_text_0_value
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
# [5 rows x 176 columns]

# %%
keep_cols = [ 
    "id",
    "name", 
    "image_path", 
    "thumbnail_url", 
    "visible_impression_info_amplitude_category_l1_name"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url",
    "visible_impression_info_amplitude_category_l1_name": "category"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#           id                                              title  \
# 0  278226869  Laptop Dell Inspiron 3530 71043887( Core i5-13...
# 1  278226504  Laptop Dell Inspiron 15 3530 N3530-i3U085W11SL...
# 2  278078317  Asus Vivobook S 14 Flip TP3402VA-LZ632W (Intel...
# 3  278078298  Asus Vivobook 15 X1502VA-BQ886W (Intel Core i7...
# 4  278078286  Asus Vivobook 14 X1405VA-LY623W (Intel Core i5...
#
#                                   path  \
# 0  images/laptop/product_278226869.jpg
# 1  images/laptop/product_278226504.jpg
# 2  images/laptop/product_278078317.jpg
# 3  images/laptop/product_278078298.jpg
# 4  images/laptop/product_278078286.jpg
#
#                                                  url  \
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                            category
# 0  Laptop - Máy Vi Tính - Linh kiện
# 1  Laptop - Máy Vi Tính - Linh kiện
# 2  Laptop - Máy Vi Tính - Linh kiện
# 3  Laptop - Máy Vi Tính - Linh kiện
# 4  Laptop - Máy Vi Tính - Linh kiện

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        100 non-null    int64
#  1   title     100 non-null    object
#  2   path      100 non-null    object
#  3   url       100 non-null    object
#  4   category  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
#                  id
# count  1.000000e+02
# mean   2.527973e+08
# std    4.384160e+07
# min    6.798288e+07
# 25%    2.422272e+08
# 50%    2.757983e+08
# 75%    2.779127e+08
# max    2.784547e+08

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/laptop.xlsx", index=False)
