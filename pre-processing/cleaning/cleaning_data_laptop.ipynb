# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_laptop.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  278226504  8916945952669
# 1  278078286  8288406691059
# 2  278078281  5166127674767
# 3  278076611  2162922536735
# 4  278071899  1759391453815
#
#                                                 name  \
# 0  Laptop Dell Inspiron 15 3530 N3530-i3U085W11SL...
# 1  Asus Vivobook 14 X1405VA-LY623W (Intel Core i5...
# 2  ASUS Vivobook X1404VA-NK394W (Intel Core i3-13...
# 3  ASUS ROG Strix G16 G614JU-N3480W (Intel Core i...
# 4  Laptop Lenovo ThinkPad E14 Gen 7 21SX002QVA (I...
#
#                                              url_key  \
# 0  laptop-dell-inspiron-15-3530-n3530-i3u085w11sl...
# 1  asus-vivobook-14-x1405va-ly623w-intel-core-i5-...
# 2  asus-vivobook-x1404va-nk394w-intel-core-i3-131...
# 3  asus-rog-strix-g16-g614ju-n3480w-intel-core-i5...
# 4  laptop-lenovo-thinkpad-e14-gen-7-21sx002qva-in...
#
#                                             url_path  type  author_name  \
# 0  laptop-dell-inspiron-15-3530-n3530-i3u085w11sl...   NaN          NaN
# 1  asus-vivobook-14-x1405va-ly623w-intel-core-i5-...   NaN          NaN
# 2  asus-vivobook-x1404va-nk394w-intel-core-i3-131...   NaN          NaN
# 3  asus-rog-strix-g16-g614ju-n3480w-intel-core-i5...   NaN          NaN
# 4  laptop-lenovo-thinkpad-e14-gen-7-21sx002qva-in...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  \
# 0         NaN       Dell                NaN  ...
# 1         NaN       Asus                NaN  ...
# 2         NaN       Asus                NaN  ...
# 3         NaN       Asus                NaN  ...
# 4         NaN     Lenovo                NaN  ...
#
#    visible_impression_info_amplitude_gift_rule_ids  badges_new_3_icon  \
# 0                                              NaN                NaN
# 1                                              NaN                NaN
# 2                                              NaN                NaN
# 3                                              NaN                NaN
# 4                                              NaN                NaN
#
#   badges_new_3_icon_height badges_new_3_icon_width  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
#
#    badges_new_3_arr_text_0_value  badges_new_4_arr_text_0_value  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#   badges_new_2_icon badges_new_2_icon_height badges_new_2_icon_width  \
# 0               NaN                      NaN                     NaN
# 1               NaN                      NaN                     NaN
# 2               NaN                      NaN                     NaN
# 3               NaN                      NaN                     NaN
# 4               NaN                      NaN                     NaN
#
#   badges_new_3_arr_text_1_value
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 177 columns]

# %%
keep_cols = [ 
    "id",
    "name", 
    "image_path", 
    "thumbnail_url", 
    "visible_impression_info_amplitude_category_l1_name"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url",
    "visible_impression_info_amplitude_category_l1_name": "category"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#           id                                              title  \
# 0  278226504  Laptop Dell Inspiron 15 3530 N3530-i3U085W11SL...
# 1  278078286  Asus Vivobook 14 X1405VA-LY623W (Intel Core i5...
# 2  278078281  ASUS Vivobook X1404VA-NK394W (Intel Core i3-13...
# 3  278076611  ASUS ROG Strix G16 G614JU-N3480W (Intel Core i...
# 4  278071899  Laptop Lenovo ThinkPad E14 Gen 7 21SX002QVA (I...
#
#                           path  \
# 0  images/laptop/278226504.png
# 1  images/laptop/278078286.jpg
# 2  images/laptop/278078281.jpg
# 3  images/laptop/278076611.jpg
# 4  images/laptop/278071899.jpg
#
#                                                  url  \
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                            category
# 0  Laptop - Máy Vi Tính - Linh kiện
# 1  Laptop - Máy Vi Tính - Linh kiện
# 2  Laptop - Máy Vi Tính - Linh kiện
# 3  Laptop - Máy Vi Tính - Linh kiện
# 4  Laptop - Máy Vi Tính - Linh kiện

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        100 non-null    int64
#  1   title     100 non-null    object
#  2   path      100 non-null    object
#  3   url       100 non-null    object
#  4   category  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
#                  id
# count  1.000000e+02
# mean   2.568884e+08
# std    4.258710e+07
# min    6.798288e+07
# 25%    2.711580e+08
# 50%    2.760264e+08
# 75%    2.779372e+08
# max    2.785883e+08

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/laptop.xlsx", index=False)
