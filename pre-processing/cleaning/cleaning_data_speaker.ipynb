# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_speaker.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  277980303  4750768275106
# 1  277820438  6626294220372
# 2  277615987  5303786037377
# 3  277548884  1400365236556
# 4  277468981  5932807198908
#
#                                                 name  \
# 0  Loa Momo thông báo chuyển khoản - Tặng khay QR...
# 1       Loa Bluetooth JBL Charge 6 - Hàng chính hãng
# 2  Loa Bluetooth ngoài trời Xiaomi BHR4802GL | Ch...
# 3  Loa vi tính để bàn SUPER BASS cực đã dòng loa ...
# 4  Loa Bluetooth Mini Karaoke Không Dây, Kèm 2 Mi...
#
#                                              url_key  \
# 0  loa-momo-thong-bao-chuyen-khoan-tang-khay-qrco...
# 1  loa-bluetooth-jbl-charge-6-hang-chinh-hang-p27...
# 2  loa-bluetooth-ngoai-troi-xiaomi-bhr4802gl-chon...
# 3  loa-vi-tinh-de-ban-super-bass-cuc-da-dong-loa-...
# 4  loa-bluetooth-mini-karaoke-khong-day-kem-2-mic...
#
#                                             url_path  type  author_name  \
# 0  loa-momo-thong-bao-chuyen-khoan-tang-khay-qrco...   NaN          NaN
# 1  loa-bluetooth-jbl-charge-6-hang-chinh-hang-p27...   NaN          NaN
# 2  loa-bluetooth-ngoai-troi-xiaomi-bhr4802gl-chon...   NaN          NaN
# 3  loa-vi-tinh-de-ban-super-bass-cuc-da-dong-loa-...   NaN          NaN
# 4  loa-bluetooth-mini-karaoke-khong-day-kem-2-mic...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  badges_new_6_code  \
# 0         NaN       Momo                NaN  ...                NaN
# 1         NaN        JBL                NaN  ...                NaN
# 2         NaN     Xiaomi                NaN  ...                NaN
# 3         NaN   LuckyJQR                NaN  ...                NaN
# 4         NaN     MINIIN                NaN  ...                NaN
#
#    badges_new_6_placement badges_new_6_text_color badges_new_6_type  \
# 0                     NaN                     NaN               NaN
# 1                     NaN                     NaN               NaN
# 2                     NaN                     NaN               NaN
# 3                     NaN                     NaN               NaN
# 4                     NaN                     NaN               NaN
#
#    badges_new_4_arr_text_1_value  badges_new_4_promotions_1_icon  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#   badges_new_4_promotions_1_icon_height badges_new_4_promotions_1_icon_width  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#   badges_new_4_promotions_1_text  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#   visible_impression_info_amplitude_combo_deal_id
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
# [5 rows x 188 columns]

# %%
keep_cols = [ 
    "id",
    "name", 
    "image_path", 
    "thumbnail_url", 
    "visible_impression_info_amplitude_category_l1_name"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url",
    "visible_impression_info_amplitude_category_l1_name": "category"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#           id                                              title  \
# 0  277980303  Loa Momo thông báo chuyển khoản - Tặng khay QR...
# 1  277820438       Loa Bluetooth JBL Charge 6 - Hàng chính hãng
# 2  277615987  Loa Bluetooth ngoài trời Xiaomi BHR4802GL | Ch...
# 3  277548884  Loa vi tính để bàn SUPER BASS cực đã dòng loa ...
# 4  277468981  Loa Bluetooth Mini Karaoke Không Dây, Kèm 2 Mi...
#
#                                    path  \
# 0  images/speaker/product_277980303.jpg
# 1  images/speaker/product_277820438.jpg
# 2  images/speaker/product_277615987.jpg
# 3  images/speaker/product_277548884.jpg
# 4  images/speaker/product_277468981.jpg
#
#                                                  url  \
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                     category
# 0  Thiết Bị Số - Phụ Kiện Số
# 1  Thiết Bị Số - Phụ Kiện Số
# 2  Thiết Bị Số - Phụ Kiện Số
# 3  Thiết Bị Số - Phụ Kiện Số
# 4  Thiết Bị Số - Phụ Kiện Số

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        100 non-null    int64
#  1   title     100 non-null    object
#  2   path      100 non-null    object
#  3   url       100 non-null    object
#  4   category  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
#                  id
# count  1.000000e+02
# mean   1.942895e+08
# std    9.489663e+07
# min    1.041800e+05
# 25%    1.052515e+08
# 50%    2.526770e+08
# 75%    2.760534e+08
# max    2.781497e+08

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/speaker.xlsx", index=False)
