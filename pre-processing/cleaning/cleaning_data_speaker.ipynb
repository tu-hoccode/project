# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_speaker.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  278149617  7155229412064
# 1  277980303  4750768275106
# 2  277820438  6626294220372
# 3  277615987  5303786037377
# 4  277548884  1400365236556
#
#                                                 name  \
# 0  Loa bluetooth 5.3 PKCB 30W Super Bass TWS lên ...
# 1  Loa Momo thông báo chuyển khoản - Tặng khay QR...
# 2       Loa Bluetooth JBL Charge 6 - Hàng chính hãng
# 3  Loa Bluetooth ngoài trời Xiaomi BHR4802GL | Ch...
# 4  Loa vi tính để bàn SUPER BASS cực đã dòng loa ...
#
#                                              url_key  \
# 0  loa-bluetooth-5-3-pkcb-30w-super-bass-tws-len-...
# 1  loa-momo-thong-bao-chuyen-khoan-tang-khay-qrco...
# 2  loa-bluetooth-jbl-charge-6-hang-chinh-hang-p27...
# 3  loa-bluetooth-ngoai-troi-xiaomi-bhr4802gl-chon...
# 4  loa-vi-tinh-de-ban-super-bass-cuc-da-dong-loa-...
#
#                                             url_path  type  author_name  \
# 0  loa-bluetooth-5-3-pkcb-30w-super-bass-tws-len-...   NaN          NaN
# 1  loa-momo-thong-bao-chuyen-khoan-tang-khay-qrco...   NaN          NaN
# 2  loa-bluetooth-jbl-charge-6-hang-chinh-hang-p27...   NaN          NaN
# 3  loa-bluetooth-ngoai-troi-xiaomi-bhr4802gl-chon...   NaN          NaN
# 4  loa-vi-tinh-de-ban-super-bass-cuc-da-dong-loa-...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  \
# 0         NaN       PKCB                NaN  ...
# 1         NaN       Momo                NaN  ...
# 2         NaN        JBL                NaN  ...
# 3         NaN     Xiaomi                NaN  ...
# 4         NaN   LuckyJQR                NaN  ...
#
#    badges_new_3_promotions_0_text  badges_new_4_arr_text_1_value  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   badges_new_4_promotions_1_icon badges_new_4_promotions_1_icon_height  \
# 0                            NaN                                   NaN
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
#
#    badges_new_4_promotions_1_icon_width  badges_new_4_promotions_1_text  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
#
#   visible_impression_info_amplitude_combo_deal_id badges_new_5_icon  \
# 0                                             NaN               NaN
# 1                                             NaN               NaN
# 2                                             NaN               NaN
# 3                                             NaN               NaN
# 4                                             NaN               NaN
#
#   badges_new_5_icon_height badges_new_5_icon_width
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
#
# [5 rows x 195 columns]

# %%
keep_cols = [ 
    "id",
    "name", 
    "image_path", 
    "thumbnail_url", 
    "visible_impression_info_amplitude_category_l1_name"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url",
    "visible_impression_info_amplitude_category_l1_name": "category"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#           id                                              title  \
# 0  278149617  Loa bluetooth 5.3 PKCB 30W Super Bass TWS lên ...
# 1  277980303  Loa Momo thông báo chuyển khoản - Tặng khay QR...
# 2  277820438       Loa Bluetooth JBL Charge 6 - Hàng chính hãng
# 3  277615987  Loa Bluetooth ngoài trời Xiaomi BHR4802GL | Ch...
# 4  277548884  Loa vi tính để bàn SUPER BASS cực đã dòng loa ...
#
#                            path  \
# 0  images/speaker/278149617.png
# 1  images/speaker/277980303.png
# 2  images/speaker/277820438.jpg
# 3  images/speaker/277615987.png
# 4  images/speaker/277548884.jpg
#
#                                                  url  \
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                     category
# 0  Thiết Bị Số - Phụ Kiện Số
# 1  Thiết Bị Số - Phụ Kiện Số
# 2  Thiết Bị Số - Phụ Kiện Số
# 3  Thiết Bị Số - Phụ Kiện Số
# 4  Thiết Bị Số - Phụ Kiện Số

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        100 non-null    int64
#  1   title     100 non-null    object
#  2   path      100 non-null    object
#  3   url       100 non-null    object
#  4   category  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
#                  id
# count  1.000000e+02
# mean   1.963942e+08
# std    9.549382e+07
# min    1.041800e+05
# 25%    1.052515e+08
# 50%    2.667355e+08
# 75%    2.762523e+08
# max    2.781497e+08

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/speaker.xlsx", index=False)
