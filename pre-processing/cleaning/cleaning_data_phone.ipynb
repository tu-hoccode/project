# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_phone.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  278237932  5930715677100
# 1  278098703  2347132350953
# 2  278000720  6457781969624
# 3  277930407  8695120714637
# 4  277777809  3255173313774
#
#                                                 name  \
# 0      Điện thoại Xiaomi Redmi 14C - Hàng chính hãng
# 1  Điện thoại POCO C75 (8GB/256GB) - Hàng Chính Hãng
# 2  Điện thoại HONOR X5b Plus 4GB/128GB - Hàng chí...
# 3  Điện thoại Tecno Spark GO 1 (3GB/64GB) - Hàng ...
# 4  Điện thoại Samsung Galaxy A26 5G (8/128GB), Mặ...
#
#                                              url_key  \
# 0  dien-thoai-xiaomi-redmi-14c-hang-chinh-hang-p2...
# 1  dien-thoai-poco-c75-8gb-256gb-hang-chinh-hang-...
# 2  dien-thoai-honor-x5b-plus-4gb-128gb-hang-chinh...
# 3  dien-thoai-tecno-spark-go-1-3gb-64gb-hang-chin...
# 4  dien-thoai-samsung-galaxy-a26-5g-8-128gb-mat-l...
#
#                                             url_path  type  author_name  \
# 0  dien-thoai-xiaomi-redmi-14c-hang-chinh-hang-p2...   NaN          NaN
# 1  dien-thoai-poco-c75-8gb-256gb-hang-chinh-hang-...   NaN          NaN
# 2  dien-thoai-honor-x5b-plus-4gb-128gb-hang-chinh...   NaN          NaN
# 3  dien-thoai-tecno-spark-go-1-3gb-64gb-hang-chin...   NaN          NaN
# 4  dien-thoai-samsung-galaxy-a26-5g-8-128gb-mat-l...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  \
# 0         NaN     Xiaomi                NaN  ...
# 1         NaN       POCO                NaN  ...
# 2         NaN      Honor                NaN  ...
# 3         NaN      Tecno                NaN  ...
# 4         NaN    Samsung                NaN  ...
#
#    badges_new_7_images_0_image_width  badges_new_7_text  \
# 0                                NaN                NaN
# 1                                NaN                NaN
# 2                                NaN                NaN
# 3                                NaN                NaN
# 4                                NaN                NaN
#
#   badges_new_8_arr_text_0_value badges_new_8_arr_text_1_value  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    badges_new_8_code  badges_new_8_placement badges_new_8_text_color  \
# 0                NaN                     NaN                     NaN
# 1                NaN                     NaN                     NaN
# 2                NaN                     NaN                     NaN
# 3                NaN                     NaN                     NaN
# 4                NaN                     NaN                     NaN
#
#   badges_new_8_type quantity_sold badges_new_6_arr_text_1_value
# 0               NaN           NaN                           NaN
# 1               NaN           NaN                           NaN
# 2               NaN           NaN                           NaN
# 3               NaN           NaN                           NaN
# 4               NaN           NaN                           NaN
#
# [5 rows x 196 columns]

# %%
keep_cols = [ 
    "name", 
    "image_path", 
    "thumbnail_url"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#                                                title  \
# 0      Điện thoại Xiaomi Redmi 14C - Hàng chính hãng
# 1  Điện thoại POCO C75 (8GB/256GB) - Hàng Chính Hãng
# 2  Điện thoại HONOR X5b Plus 4GB/128GB - Hàng chí...
# 3  Điện thoại Tecno Spark GO 1 (3GB/64GB) - Hàng ...
# 4  Điện thoại Samsung Galaxy A26 5G (8/128GB), Mặ...
#
#                          path  \
# 0  images/phone/278237932.png
# 1  images/phone/278098703.png
# 2  images/phone/278000720.jpg
# 3  images/phone/277930407.png
# 4  images/phone/277777809.jpg
#
#                                                  url
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   100 non-null    object
#  1   path    100 non-null    object
#  2   url     100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB
#                                                   title  \
# count                                               100
# unique                                               99
# top     Điện Thoại Oppo A58 6GB/128GB - Hàng Chính Hãng
# freq                                                  2
#
#                               path  \
# count                          100
# unique                         100
# top     images/phone/278237932.png
# freq                             1
#
#                                                       url
# count                                                 100
# unique                                                100
# top     https://salt.tikicdn.com/cache/280x280/ts/prod...
# freq                                                    1

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/phone.xlsx", index=False)
