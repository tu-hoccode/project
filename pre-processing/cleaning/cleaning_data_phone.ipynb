# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_phone.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  278237932  5930715677100
# 1  278098703  5570280517992
# 2  278000720  6457781969624
# 3  277930407  8695120714637
# 4  277777809  4865918741583
#
#                                                 name  \
# 0      Điện thoại Xiaomi Redmi 14C - Hàng chính hãng
# 1  Điện thoại POCO C75 (8GB/256GB) - Hàng Chính Hãng
# 2  Điện thoại HONOR X5b Plus 4GB/128GB - Hàng chí...
# 3  Điện thoại Tecno Spark GO 1 (3GB/64GB) - Hàng ...
# 4  Điện thoại Samsung Galaxy A26 5G (8/128GB), Mặ...
#
#                                              url_key  \
# 0  dien-thoai-xiaomi-redmi-14c-hang-chinh-hang-p2...
# 1  dien-thoai-poco-c75-8gb-256gb-hang-chinh-hang-...
# 2  dien-thoai-honor-x5b-plus-4gb-128gb-hang-chinh...
# 3  dien-thoai-tecno-spark-go-1-3gb-64gb-hang-chin...
# 4  dien-thoai-samsung-galaxy-a26-5g-8-128gb-mat-l...
#
#                                             url_path  type  author_name  \
# 0  dien-thoai-xiaomi-redmi-14c-hang-chinh-hang-p2...   NaN          NaN
# 1  dien-thoai-poco-c75-8gb-256gb-hang-chinh-hang-...   NaN          NaN
# 2  dien-thoai-honor-x5b-plus-4gb-128gb-hang-chinh...   NaN          NaN
# 3  dien-thoai-tecno-spark-go-1-3gb-64gb-hang-chin...   NaN          NaN
# 4  dien-thoai-samsung-galaxy-a26-5g-8-128gb-mat-l...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  badges_new_7_text  \
# 0         NaN     Xiaomi                NaN  ...                NaN
# 1         NaN       POCO                NaN  ...                NaN
# 2         NaN      Honor                NaN  ...                NaN
# 3         NaN      Tecno                NaN  ...                NaN
# 4         NaN    Samsung                NaN  ...                NaN
#
#    badges_new_8_arr_text_0_value badges_new_8_code badges_new_8_placement  \
# 0                            NaN               NaN                    NaN
# 1                            NaN               NaN                    NaN
# 2                            NaN               NaN                    NaN
# 3                            NaN               NaN                    NaN
# 4                            NaN               NaN                    NaN
#
#    badges_new_8_text_color  badges_new_8_type  \
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                      NaN                NaN
# 4                      NaN                NaN
#
#   visible_impression_info_amplitude_discounted_by_rule_ids  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   badges_new_8_arr_text_1_value badges_new_6_arr_text_1_value quantity_sold
# 0                           NaN                           NaN           NaN
# 1                           NaN                           NaN           NaN
# 2                           NaN                           NaN           NaN
# 3                           NaN                           NaN           NaN
# 4                           NaN                           NaN           NaN
#
# [5 rows x 198 columns]

# %%
keep_cols = [ 
    "id",
    "name", 
    "image_path", 
    "thumbnail_url", 
    "visible_impression_info_amplitude_category_l1_name"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "visible_impression_info_amplitude_category_l1_name": "category"
}
df = df.rename(columns=rename_dict)

# %%
df
# Out:
#            id                                              title  \
# 0   278237932      Điện thoại Xiaomi Redmi 14C - Hàng chính hãng
# 1   278098703  Điện thoại POCO C75 (8GB/256GB) - Hàng Chính Hãng
# 2   278000720  Điện thoại HONOR X5b Plus 4GB/128GB - Hàng chí...
# 3   277930407  Điện thoại Tecno Spark GO 1 (3GB/64GB) - Hàng ...
# 4   277777809  Điện thoại Samsung Galaxy A26 5G (8/128GB), Mặ...
# ..        ...                                                ...
# 95  276500230  Máy đọc sách Kindle Colorsoft Signature Editio...
# 96  276489194  Điện thoại Samsung Galaxy S24 FE - Hàng chính ...
# 97  276465090  Combo Máy đọc sách Amazon Kindle Paperwhite 6 ...
# 98  276099688  Xiaomi Redmi Note 12 5G 8GB/128GB ,Màn AMOLED ...
# 99  276062770  Điện Thoại Xiaomi Redmi 14C 4GB/128GB - Hàng C...
#
#                             image_path  \
# 0   images/phone/product_278237932.jpg
# 1   images/phone/product_278098703.jpg
# 2   images/phone/product_278000720.jpg
# 3   images/phone/product_277930407.jpg
# 4   images/phone/product_277777809.jpg
# ..                                 ...
# 95  images/phone/product_276500230.jpg
# 96  images/phone/product_276489194.jpg
# 97  images/phone/product_276465090.jpg
# 98  images/phone/product_276099688.jpg
# 99  images/phone/product_276062770.jpg
#
#                                         thumbnail_url  \
# 0   https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1   https://salt.tikicdn.com/cache/280x280/ts/prod...
# 2   https://salt.tikicdn.com/cache/280x280/ts/prod...
# 3   https://salt.tikicdn.com/cache/280x280/ts/prod...
# 4   https://salt.tikicdn.com/cache/280x280/ts/prod...
# ..                                                ...
# 95  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 96  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 97  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 98  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 99  https://salt.tikicdn.com/cache/280x280/ts/prod...
#
#                       category
# 0   Điện Thoại - Máy Tính Bảng
# 1   Điện Thoại - Máy Tính Bảng
# 2   Điện Thoại - Máy Tính Bảng
# 3   Điện Thoại - Máy Tính Bảng
# 4   Điện Thoại - Máy Tính Bảng
# ..                         ...
# 95  Điện Thoại - Máy Tính Bảng
# 96  Điện Thoại - Máy Tính Bảng
# 97  Điện Thoại - Máy Tính Bảng
# 98  Điện Thoại - Máy Tính Bảng
# 99  Điện Thoại - Máy Tính Bảng
#
# [100 rows x 5 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             100 non-null    int64
#  1   title          100 non-null    object
#  2   image_path     100 non-null    object
#  3   thumbnail_url  100 non-null    object
#  4   category       100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
#                  id
# count  1.000000e+02
# mean   2.582560e+08
# std    4.806957e+07
# min    1.125177e+07
# 25%    2.743521e+08
# 50%    2.765772e+08
# 75%    2.774447e+08
# max    2.782379e+08

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/phone.xlsx", index=False)
