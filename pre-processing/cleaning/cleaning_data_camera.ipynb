# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_camera.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  277854019  8795204295382
# 1  277601288  5980799827064
# 2  277417151  3367749795649
# 3  277015260  7607448837870
# 4  276857147  1981200159179
#
#                                                 name  \
# 0                        Đồng hồ đo Áp suất lốp Ô tô
# 1  Camera wifi Yoosee Ngoài Trời 20MPX 4 Mắt 3 Mà...
# 2  Camera Yoosee Wifi Ngoài Trời 2 Mắt Xem Cùng L...
# 3  Pin Dành Cho Máy Ảnh Nikon EN-EL14 1500mAh Cao...
# 4  Thẻ Vietmap Live Pro Chính Hãng 2025, cảnh báo...
#
#                                              url_key  \
# 0             dong-ho-do-ap-suat-lop-o-to-p277854019
# 1  camera-wifi-yoosee-ngoai-troi-20mpx-4-mat-3-ma...
# 2  camera-yoosee-wifi-ngoai-troi-2-mat-xem-cung-l...
# 3  pin-danh-cho-may-anh-nikon-en-el14-1500mah-cao...
# 4  the-vietmap-live-pro-chinh-hang-2025-canh-bao-...
#
#                                             url_path  type  author_name  \
# 0  dong-ho-do-ap-suat-lop-o-to-p277854019.html?sp...   NaN          NaN
# 1  camera-wifi-yoosee-ngoai-troi-20mpx-4-mat-3-ma...   NaN          NaN
# 2  camera-yoosee-wifi-ngoai-troi-2-mat-xem-cung-l...   NaN          NaN
# 3  pin-danh-cho-may-anh-nikon-en-el14-1500mah-cao...   NaN          NaN
# 4  the-vietmap-live-pro-chinh-hang-2025-canh-bao-...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  \
# 0         NaN        OEM                NaN  ...
# 1         NaN     Yoosee                NaN  ...
# 2         NaN     Yoosee                NaN  ...
# 3         NaN      ROGTZ                NaN  ...
# 4         NaN    VietMap                NaN  ...
#
#    badges_new_6_arr_text_0_value  badges_new_6_code badges_new_6_placement  \
# 0                            NaN                NaN                    NaN
# 1                            NaN                NaN                    NaN
# 2                            NaN                NaN                    NaN
# 3                            NaN                NaN                    NaN
# 4                            NaN                NaN                    NaN
#
#   badges_new_6_text_color badges_new_6_type  \
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
#
#   badges_new_4_images_0_image_height badges_new_4_images_0_image_url  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#   badges_new_4_images_0_image_width badges_new_5_arr_text_1_value  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
#
#   visible_impression_info_amplitude_gift_rule_ids
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
# [5 rows x 202 columns]

# %%
keep_cols = [ 
    "id",
    "name", 
    "image_path", 
    "thumbnail_url", 
    "visible_impression_info_amplitude_category_l1_name"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url",
    "visible_impression_info_amplitude_category_l1_name": "category"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#           id                                              title  \
# 0  277854019                        Đồng hồ đo Áp suất lốp Ô tô
# 1  277601288  Camera wifi Yoosee Ngoài Trời 20MPX 4 Mắt 3 Mà...
# 2  277417151  Camera Yoosee Wifi Ngoài Trời 2 Mắt Xem Cùng L...
# 3  277015260  Pin Dành Cho Máy Ảnh Nikon EN-EL14 1500mAh Cao...
# 4  276857147  Thẻ Vietmap Live Pro Chính Hãng 2025, cảnh báo...
#
#                           path  \
# 0  images/camera/277854019.jpg
# 1  images/camera/277601288.jpg
# 2  images/camera/277417151.jpg
# 3  images/camera/277015260.jpg
# 4  images/camera/276857147.jpg
#
#                                                  url                 category
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...  Máy Ảnh - Máy Quay Phim
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...  Máy Ảnh - Máy Quay Phim
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...  Máy Ảnh - Máy Quay Phim
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...  Máy Ảnh - Máy Quay Phim
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...  Máy Ảnh - Máy Quay Phim

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        100 non-null    int64
#  1   title     100 non-null    object
#  2   path      100 non-null    object
#  3   url       100 non-null    object
#  4   category  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
#                  id
# count  1.000000e+02
# mean   2.150549e+08
# std    8.631726e+07
# min    4.688897e+06
# 25%    1.793600e+08
# 50%    2.709771e+08
# 75%    2.752751e+08
# max    2.779654e+08

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/camera.xlsx", index=False)
