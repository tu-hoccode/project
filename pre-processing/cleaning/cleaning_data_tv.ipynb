# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import unicodedata

# %%
df = pd.read_excel("../../crawl_data/data/data_tv.xlsx")

# %%
df.head()
# Out:
#           id            sku  \
# 0  278220734  2004742899164
# 1  278138258  5502954751332
# 2  278138206  6189447443433
# 3  278077419  1516540466887
# 4  278077327  2768528301218
#
#                                                 name  \
# 0  [NEW 2026 TV Series] Smart Tivi Xiaomi TV A Pr...
# 1  Smart Tivi LG AI 4K 55 Inch 55UA8450PSA- Hàng ...
# 2  Smart Tivi LG AI 4K 65 Inch 65UA8450PSA- Hàng ...
# 3  Google Tivi Xiaomi A 2026 4K 55 inch L55MB-ASE...
# 4  Google Tivi Xiaomi A 2026 4K 43 inch L43MB-AUS...
#
#                                              url_key  \
# 0  new-2026-tv-series-smart-tivi-xiaomi-tv-a-pro-...
# 1  smart-tivi-lg-ai-4k-55-inch-55ua8450psa-hang-c...
# 2  smart-tivi-lg-ai-4k-65-inch-65ua8450psa-hang-c...
# 3  google-tivi-xiaomi-a-2026-4k-55-inch-l55mb-ase...
# 4  google-tivi-xiaomi-a-2026-4k-43-inch-l43mb-aus...
#
#                                             url_path  type  author_name  \
# 0  new-2026-tv-series-smart-tivi-xiaomi-tv-a-pro-...   NaN          NaN
# 1  smart-tivi-lg-ai-4k-55-inch-55ua8450psa-hang-c...   NaN          NaN
# 2  smart-tivi-lg-ai-4k-65-inch-65ua8450psa-hang-c...   NaN          NaN
# 3  google-tivi-xiaomi-a-2026-4k-55-inch-l55mb-ase...   NaN          NaN
# 4  google-tivi-xiaomi-a-2026-4k-43-inch-l43mb-aus...   NaN          NaN
#
#    book_cover brand_name  short_description  ...  \
# 0         NaN     Xiaomi                NaN  ...
# 1         NaN         LG                NaN  ...
# 2         NaN         LG                NaN  ...
# 3         NaN     Xiaomi                NaN  ...
# 4         NaN     Xiaomi                NaN  ...
#
#    badges_new_3_promotions_0_icon_height  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    badges_new_3_promotions_0_icon_width badges_new_3_promotions_0_text  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#   visible_impression_info_amplitude_ineligible_coupon_rule_id  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    badges_new_2_icon  badges_new_2_icon_height badges_new_2_icon_width  \
# 0                NaN                       NaN                     NaN
# 1                NaN                       NaN                     NaN
# 2                NaN                       NaN                     NaN
# 3                NaN                       NaN                     NaN
# 4                NaN                       NaN                     NaN
#
#   badges_new_4_icon badges_new_4_icon_height badges_new_4_icon_width
# 0               NaN                      NaN                     NaN
# 1               NaN                      NaN                     NaN
# 2               NaN                      NaN                     NaN
# 3               NaN                      NaN                     NaN
# 4               NaN                      NaN                     NaN
#
# [5 rows x 163 columns]

# %%
keep_cols = [ 
    "id",
    "name", 
    "image_path", 
    "thumbnail_url", 
    "visible_impression_info_amplitude_category_l1_name"
]

# %%
df = df[keep_cols]

# %%
rename_dict = {
    "name": "title",
    "image_path": "path",
    "thumbnail_url": "url",
    "visible_impression_info_amplitude_category_l1_name": "category"
}
df = df.rename(columns=rename_dict)

# %%
df.head(5)
# Out:
#           id                                              title  \
# 0  278220734  [NEW 2026 TV Series] Smart Tivi Xiaomi TV A Pr...
# 1  278138258  Smart Tivi LG AI 4K 55 Inch 55UA8450PSA- Hàng ...
# 2  278138206  Smart Tivi LG AI 4K 65 Inch 65UA8450PSA- Hàng ...
# 3  278077419  Google Tivi Xiaomi A 2026 4K 55 inch L55MB-ASE...
# 4  278077327  Google Tivi Xiaomi A 2026 4K 43 inch L43MB-AUS...
#
#                               path  \
# 0  images/tv/product_278220734.jpg
# 1  images/tv/product_278138258.jpg
# 2  images/tv/product_278138206.jpg
# 3  images/tv/product_278077419.jpg
# 4  images/tv/product_278077327.jpg
#
#                                                  url             category
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...  Điện Tử - Điện Lạnh
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...  Điện Tử - Điện Lạnh
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...  Điện Tử - Điện Lạnh
# 3  https://salt.tikicdn.com/cache/280x280/ts/prod...  Điện Tử - Điện Lạnh
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...  Điện Tử - Điện Lạnh

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        100 non-null    int64
#  1   title     100 non-null    object
#  2   path      100 non-null    object
#  3   url       100 non-null    object
#  4   category  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB
#                  id
# count  1.000000e+02
# mean   2.534201e+08
# std    5.662742e+07
# min    2.003079e+06
# 25%    2.748706e+08
# 50%    2.756033e+08
# 75%    2.768611e+08
# max    2.782207e+08

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_excel("../data_cleaned/tv.xlsx", index=False)
